# %% [markdown]
# # Voice-controlled AI agent

# %% [markdown]
# ## First steps
#
# - Select HDMI display for audio output
#
# - Find the microphone device number
#
# - Hand-eye calibration (the process of determining the precise spatial relationship between a robot's end effector (the "hand") and a camera (the "eye"), enabling coordinated perception and manipulation)

# %% [markdown]
# # Functions that the agent can call

# %%
# funciton 1： back_zero
# back_zero()

# function 2： relax arms
# relax_arms()

# function 3： head shake
# head_shake()

# function 4： head nod
# head_nod()

# function 5： head dance
# head_dance()

# function 6： pump on
# pump_on()

# function 7： pump off
# pump_off()

# function 8： move to coordinates
# move_to_coords(X=150, Y=-120)

# function 9： single joint move
# single_joint_move(1, 60)

# function 10：move to top view
# move_to_top_view()

# function 11： top view shot
# top_view_shot()

# function 12： check and turn on camera
# check_camera()

# function 13： change LED color
# llm_led('Help me change the color of the LED light to the color of Lake Baikal')

# function 14：move object
# vlm_move(PROMPT='Help me put the red block on Peppa Pig')

# function 15：drag and teach
# drag_teach()

# function 16：sleep and wait
# time.sleep()
